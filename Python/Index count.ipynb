# %%
index_count = 1
word = input("Type in any word: ")

for letter in word:
    print('At index {} the letter is {}'.format(index_count,letter))
    index_count += 1
# Out:
# Type in any word: pneumonoultramicroscopicsilicovolcanoconiosis floccinaucinihilipilification antidisestablishmentarianism
# At index 1 the letter is p
# At index 2 the letter is n
# At index 3 the letter is e
# At index 4 the letter is u
# At index 5 the letter is m
# At index 6 the letter is o
# At index 7 the letter is n
# At index 8 the letter is o
# At index 9 the letter is u
# At index 10 the letter is l
# At index 11 the letter is t
# At index 12 the letter is r
# At index 13 the letter is a
# At index 14 the letter is m
# At index 15 the letter is i
# At index 16 the letter is c
# At index 17 the letter is r
# At index 18 the letter is o
# At index 19 the letter is s
# At index 20 the letter is c
# At index 21 the letter is o
# At index 22 the letter is p
# At index 23 the letter is i
# At index 24 the letter is c
# At index 25 the letter is s
# At index 26 the letter is i
# At index 27 the letter is l
# At index 28 the letter is i
# At index 29 the letter is c
# ...
