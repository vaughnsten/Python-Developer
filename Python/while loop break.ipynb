# %%
my_input = input("Type any number to be added by 1: ")

while int(my_input) <= 100:
    print(f"The current value of your given number is {my_input}")
    my_input = int(my_input) + 1
    if my_input > 100:
        break
else:
    print("Your number is greater than 100")
# Out:
# Type any number to be added by 1: 1
# The current value of your given number is 1
# The current value of your given number is 2
# The current value of your given number is 3
# The current value of your given number is 4
# The current value of your given number is 5
# The current value of your given number is 6
# The current value of your given number is 7
# The current value of your given number is 8
# The current value of your given number is 9
# The current value of your given number is 10
# The current value of your given number is 11
# The current value of your given number is 12
# The current value of your given number is 13
# The current value of your given number is 14
# The current value of your given number is 15
# The current value of your given number is 16
# The current value of your given number is 17
# The current value of your given number is 18
# The current value of your given number is 19
# The current value of your given number is 20
# ...
